# %% [markdown]
# <a href="https://colab.research.google.com/github/evelinachom-create/12.09.26/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_points = 0
print("Тест на логіку")
print("")
print("Продовжіть числовий ряд: 1, 3, 5, 7, ...")
print("a) 8")
print("b) 9")
print("c) 5")
print("d) 10")
answer = input("")
if answer == "b":
  total_points = total_points + 1

print("Яке число пропущено в рядку: 2, 4, ... , 16, 32, 64?")
print("a) 6")
print("b) 10")
print("c) 8")
print("d) 12")
answer = input("")
if answer == "c":
  total_points = total_points + 1

print("Яке число порушує послідовність: 22, 21, 19, 16, 12, 7, 0 ?")
print("a) 7")
print("b) 21")
print("c) 16")
print("d) 0")
answer = input("")
if answer == "d":
  total_points = total_points + 1

print("Продовжіть числовий ряд: 2, 3, 5, 8, 12, 17, ...")
print("a) 23")
print("b) 15")
print("c) 14")
print("d) 18")
answer = input("")
if answer == "a":
  total_points = total_points + 1


  print()
print("Ваш результат:", total_points, "балів")
if total_points >= 3:
  print("Усе правильно!")
else:
  print("Обдумай відповіді ретельніше!")
# Out:
# Тест на логіку
#
# Продовжіть числовий ряд: 1, 3, 5, 7, ...
# a) 8
# b) 9
# c) 5
# d) 10
